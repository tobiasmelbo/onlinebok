# %% [markdown]
# # Matematikk 1T 📗
#
# Dette kapitlet inneholder noen forskjellige programmeringsprosjekter ment for Matematikk 1T.
#
# ```{admonition} Til læreren 🧑‍🏫
# :class: note
# Til hvert delkapittel står det hvilke andre delkapitler som er en forutsetning. Det er lurt å ha vært gjennom {ref}`Grunnleggende Python` før man begynner her.
# ```
