# %% [markdown]
# ### Vekstfaktor
#
# Vekstfaktor er det tallet man ganger med for at noe skal endre seg med en viss prosent.
#
# ::::{grid} 3
# :gutter: 1
#
# :::{grid-item-card} Endring
# :::
#
# :::{grid-item-card} Prosentfaktor
# :::
#
# :::{grid-item-card} Vekstfaktor
# :::
#
# :::{grid-item-card}
# $20\%$ økning
# :::
#
# :::{grid-item-card}
# $0.20$
# :::
#
# :::{grid-item-card}
# $v=1.20$
# :::
#
# :::{grid-item-card}
# $10\%$ økning
# :::
#
# :::{grid-item-card}
# $0.10$
# :::
#
# :::{grid-item-card}
# $v=1.10$
# :::
#
# :::{grid-item-card}
# $5\%$ økning
# :::
#
# :::{grid-item-card}
# $0.05$
# :::
#
# :::{grid-item-card}
# $v=1.05$
# :::
#
# :::{grid-item-card}
# $5\%$ reduksjon
# :::
#
# :::{grid-item-card}
# $0.05$
# :::
#
# :::{grid-item-card}
# $v=0.95$
# :::
#
# :::{grid-item-card}
# $10\%$ reduksjon
# :::
#
# :::{grid-item-card}
# $0.10$
# :::
#
# :::{grid-item-card}
# $v=0.90$
# :::
#
# :::{grid-item-card}
# $20\%$ reduksjon
# :::
#
# :::{grid-item-card}
# $0.20$
# :::
#
# :::{grid-item-card}
# $v=0.80$
# :::
#
#
# ::::

# %% [markdown]
# #### Programmering av vekstfaktor med `for`
#
# La oss se på et eksempel. Jeg setter inn $10\,000$ kr i en bankkonto med $5\%$ årlig rente. Hvor mye får jeg i rente hvert år og hvordan vil pengene mine se ut i de neste årene?

# %%
år = 0
penger = 10000
prosentfaktor = 0.05
vekstfaktor = 1 + prosentfaktor
print(år, penger)

for n in range(4):
    år = år + 1
    penger = penger * vekstfaktor
    print(år, round(penger, 2))
# Out:
# 0 10000
# 1 10500.0
# 2 11025.0
# 3 11576.25
# 4 12155.06

# %% [markdown]
# Jeg kan også finne hvor mye rente jeg har fått hvert år ved å gange pengene med prosentfaktoren.

# %%
år = 0
penger = 10000
prosentfaktor = 0.05
vekstfaktor = 1 + prosentfaktor
print(år, penger)

for n in range(5):
    år = år + 1
    rente = penger * prosentfaktor
    print("Rente:", rente)
    penger = penger * vekstfaktor
    print(år, round(penger, 2))
# Out:
# 0 10000
# Rente: 500.0
# 1 10500.0
# Rente: 525.0
# 2 11025.0
# Rente: 551.25
# 3 11576.25
# Rente: 578.8125
# 4 12155.06
# Rente: 607.7531250000001
# 5 12762.82

# %% [markdown]
# #### Programmering av vekstfaktor med `while`
#
# Hvis vi ikke helt vet hvor mange ganger en løkke skal kjøre passer en `while`-løkke bedre.
#
# La oss si at jeg har en bil til $200\,000$ kr. Den avtar i verdi med $9\%$ hvert år. Hvor mange år går det før den har blitt verdt $50\,000$ kr?

# %%
år = 0
verdi = 200000
prosentfaktor = 0.09
vekstfaktor = 1 - prosentfaktor
print(år, verdi)

while verdi > 50000:
    år = år + 1
    verdi = verdi * vekstfaktor
    print(år, verdi)
# Out:
# 0 200000
# 1 182000.0
# 2 165620.0
# 3 150714.2
# 4 137149.92200000002
# 5 124806.42902000003
# 6 113573.85040820003
# 7 103352.20387146203
# 8 94050.50552303044
# 9 85585.96002595771
# 10 77883.22362362152
# 11 70873.73349749559
# 12 64495.09748272099
# 13 58690.5387092761
# 14 53408.39022544125
# 15 48601.635105151545

# %% [markdown]
# Det har altså tatt $15$ år før verdien har blitt under $50\,000$ kr.

# %% [markdown]
# ---
#
# #### Oppgaver
#
# ##### Oppgave 1 🦠
#
# I en skål ligger det $200\,000$ bakterier. Antallet bakterier øker med 40% hvert minutt.
#
# Hvor lang tid tar det før det er over $2\,000\,000$ bakterier?
#
# ##### Oppgave 2 💸
#
# Jeg har $20\,000$ kr på sparekonto. Hvert år setter jeg inn $27\,500$ kr. Renten er på $5.5\%$.
#
# Hvor lang tid tar det før jeg har over $300\,000$ kr på konto?
#
# ##### Oppgave 3 🧙‍♀️
#
# Ånei! En heks har kastet en forbannelse på meg som gjør at jeg krymper. Jeg er $180$ cm høy nå, men jeg krymper $1\%$ per år.
#
# a) Hvor lang tid tar det før jeg blir under $100$ cm høy?
#
# ````{admonition} Løsningsforslag
# :class: note, dropdown
# ```
# år = 0
# høyde = 180
# prosentfaktor = 0.01
# vekstfaktor = 1 - prosentfaktor
#
# while høyde > 100:
#     år = år + 1
#     høyde = høyde * vekstfaktor
#
# print(år, høyde)
# ```
# Når det har gått $59$ år, har jeg blitt under $100$ cm høy.
# ````
#
# Det viser seg at forbannelsen blir sterkere over tid! Forbannelsen dobles faktisk hvert år, slik at hvis jeg krymper $1\%$ det første året, så krymper jeg $2\%$ året etter, og $4\%$ året etter det igjen.
#
# b) Hvor lang tid tar det før jeg blir $100$ cm høy nå?
#
# ````{admonition} Løsningsforslag
# :class: note, dropdown
# ```
# år = 0
# høyde = 180
# prosentfaktor = 0.01
# vekstfaktor = 1 - prosentfaktor
#
# while høyde > 100:
#     år = år + 1
#     høyde = høyde * vekstfaktor
#     prosentfaktor = prosentfaktor * 2
#     vekstfaktor = 1 - prosentfaktor
#
# print(år, høyde)
# ```
# Når det har gått $6$ år, har jeg blitt under $100$ cm høy.
# ````
