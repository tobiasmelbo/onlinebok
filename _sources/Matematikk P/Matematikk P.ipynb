# %% [markdown]
# # Matematikk P 📕
#
# Denne delen går gjennom noen programmeringseksempler ment for P-matten (P, 2P, 2P-Y osv...).
#
# ```{admonition} Til læreren 🧑‍🏫
# :class: note
# Det er lurt å ha vært gjennom det meste av {ref}`Grunnleggende Python` før man begynner her. {ref}`Lister` og {ref}`Funksjoner` ser ikke ut som at er nødvendig for å kunne løse eksamensoppgavene... *enda*.
# ```
