# %% [markdown]
# (Vilkår)=
# ### Vilkår
#
# Vilkår (*`if`-statements*) er en måte for å sjekke om et utsagn er sant, og så gjøre en del av koden bare *dersom* det er sant. Da kan programmet reagere ulikt til forskjellige scenarioer.
#
# #### Utsagn
#
# Utsagn er påstander som kan være sanne eller usanne. `True` eller `False`.
#
# Først må vi lære en måte å uttrykke utsagn på. Dette kan vi gjøre med symboler som vi kaller sammenlikningsoperatorer.
#
# Under er en oversikt over disse.

# %% [markdown]
# ::::{grid} 2
# :gutter: 1
#
# :::{grid-item-card}
# **Operator**
# :::
#
# :::{grid-item-card}
# **Betydning**
# :::
#
# :::{grid-item-card}
# `==`
# :::
#
# :::{grid-item-card}
# Lik
# :::
#
# :::{grid-item-card}
# `!=`
# :::
#
# :::{grid-item-card}
# Ikke lik
# :::
#
# :::{grid-item-card}
# `>`
# :::
#
# :::{grid-item-card}
# Større enn
# :::
#
# :::{grid-item-card}
# `<`
# :::
#
# :::{grid-item-card}
# Mindre enn
# :::
#
# :::{grid-item-card}
# `>=`
# :::
#
# :::{grid-item-card}
# Større enn, eller lik.
# :::
#
# :::{grid-item-card}
# `<=`
# :::
#
# :::{grid-item-card}
# Mindre enn, eller lik.
# :::
#
# ::::

# %% [markdown]
# Her kommer det noen eksempler på utsagn.

# %%
print(1 == 2)
print(1 != 2)
print(1 > 2)
print(1 < 2)
print(1 >= 2)
print(1 <= 2)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# Der vi får `False` er utsagnet galt. Der vi får `True` er utsagnet riktig. Gå igjennom eksempelet og sørg for at du forstår hvorfor det blir skrevet ut `True` eller `False` for de forskjellige utsagnene.

# %% [markdown]
# #### Vilkår
#
# Nå kan vi begynne å skrive vilkår.

# %%
a = 2
b = 3

if a < b:
    print("a er mindre enn b")
# Out:
# a er mindre enn b

# %% [markdown]
# Legg merke til at linjen med `print()` er skrevet med et innrykk. Dette kan du lage selv ved å trykke på TAB-knappen på tastaturet. Det som er skrevet med innrykk etter et vilkår (`if a < b:`) skjer bare dersom utsagnet (`a < b`) er sant.
#
# Forsøk å endre programmet slik at `a` ikke er mindre enn `b`. Da vil du se at linjen med `print()` ikke gjennomføres.
#
# Vi kan også sjekke flere ulike scenarioer.

# %%
a = 3
b = 3

if a < b:
    print("a er mindre enn b")
elif a == b:
    print("a er lik b")
else:
    print("a er større enn b")
# Out:
# a er lik b

# %% [markdown]
# Her bruker vi `elif` og `else` for å sjekke flere forskjellige muligheter. `elif` er en forkortelse for else if, og betyr *eller hvis*. `else` betyr *ellers*.
#
# Programmet over kan leses på denne måten:
#
# - Hvis `a` er mindre enn `b` så skriver vi *a er mindre enn b*
# - ... eller hvis `a` er lik `b` så skriver vi *a er lik b*
# - ... ellers skriver vi *a er større enn b*.

# %% [markdown]
# ---
#
# #### Oppgaver
#
# ##### Oppgave 1
#
# I denne oppgaven skal du lage utsagn og skrive ut sannhetsverdier.
#
# ```
# print(1 == 1) # Skriver ut True
# ```
#
# 1. Lag et utsagn som gir `True` og bruker operatoren `==`
# 2. Lag et utsagn som gir `True` og bruker operatoren `>`
# 3. Lag et utsagn som gir `True` og bruker operatoren `!=`
# 4. Lag et utsagn som gir `False` og bruker operatoren `==`
# 5. Lag et utsagn som gir `False` og bruker operatoren `<`
# 6. Lag et utsagn som gir `False` og bruker operatoren `>=`
#
# ##### Oppgave 2
# > *Se {ref}`Kalkulatorer og pakker` for hvordan man kan få input og generere tilfeldige tall*.
#
# I denne oppgaven skal vi lage et program som trener oss på gangetabellen.
#
# 1. Lag en variabel `a` og en variabel `b`. Begge skal være tilfeldige tall mellom `1` og `9`.
# 2. Skriv ut "Hva er `a` ganger `b`?"
# 3. Lag en variabel `svar` som skal være et tall fra brukerens input.
#
# Hvis svaret er riktig skal programmet skrive ut at svaret er riktig. Hvis svaret er feil skal programmet skrive ut at svaret er feil og hva som er det riktige svaret.
#
# ##### Oppgave 3
#
# > *Se {ref}`Kalkulatorer og pakker` for hvordan man kan generere tilfeldige tall*.
#
# I rollespill som *Dungeons & Dragons* 🎲 bruker man ofte en 20-sidet terning.
#
# En trollmann 🧙‍♂️ skal slå en zombie 🧟 med staven sin.
#
# For at trollmannen skal treffe, så må terningkastet `d` være høyere enn beskyttelsesgraden til zombien.
#
# En zombie har beskyttelsesgrad `8`.
#
# 1. Lag en variabel `d` som skal være et tilfeldig tall mellom `1` og `20`.
# 2. Skriv ut verdien til `d`.
# 3. Skriv ut *Trollmannen treffer!* hvis `d` er høyere enn eller lik `8`, eller *Trollmannen bommer!* hvis `d` er lavere enn `8`.
#
# Bonus:
#
# Dersom man er veldig heldig eller uheldig skjer det ofte gøyale ting i *Dungeons & Dragons*.
#
# - Hvis man ruller en `20` får man en *critical success* 🏆
#
# - Hvis man ruller en `1` får man en *critical failure* 😬
#
# Utvid programmet ditt til å få med disse utfallene. Inkluder gjerne en gøyal utskrift for den heldige, eller uheldige, trollmannen.
