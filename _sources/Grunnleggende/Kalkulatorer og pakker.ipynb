# %% [markdown]
# (Kalkulatorer og pakker)=
# ### Kalkulatorer og pakker
#
# I denne delen skal vi lære hvordan vi kan bruke pakker, lage enkle kalkulatorer og generere tilfeldige tall.
#
# #### Pakker
#
# Python har mange innebygde funksjoner, men noen funksjoner ligger i pakker som vi må importere. Det finnes utrolig mange pakker og noen av disse har utrolig mange funksjoner, men vi skal ta noen funksjoner fra noen få pakker.

# %% [markdown]
# ##### `math`-pakken
#
# Pakken `math` gir oss flere nyttige verktøy.
#
# - `math.sqrt(<tall>)` er en funksjon som gir oss kvadratroten av et tall.
# - `math.pi` gir oss $\pi$.
#
# Her er noen eksempler.

# %%
import math

print(math.sqrt(4))     # Gir oss kvadratroten av 4.
print(math.pi)          # Gir oss pi.
# Out:
# 2.0

# %% [markdown]
# Man kan også importere bare de tingene man trenger. Det kan gjøre koden litt enklere.

# %%
from math import sqrt, pi

print(sqrt(4))
print(pi)
# Out:
# 2.0
# 3.141592653589793

# %% [markdown]
# (random-pakken)=
# ##### `random`-pakken
#
# Pakken `random` gir oss tilfeldige tall. Ikke bare er det gøy å leke med, men det er også nyttig for å simulere ting.
#
# - `random.random()` er en funksjon som gir oss et tilfeldig tall fra og med null og opp til 1. Altså $[0,1\rangle$.
# - `random.randint(<start>, <slutt>)` er en funksjon som gir oss et tifeldig tall fra og med startverdien til og med sluttverdien.
#
# Her er noen eksempler

# %%
from random import random, randint

print(random())      # Gir oss et tilfeldig tall fra og med null og opp til 1.
print(randint(1,6))  # Gir oss et tall fra og med 1 til og med 6 (akkurat som et terningkast).
# Out:
# 0.7931440428598878
# 2

# %% [markdown]
# #### Input
#
# Vi kan ta input fra brukeren med `input()`-funksjonen.
#
# ```
# navn = input("Navn: ")
# print("Hei,", navn)
# ```
#
# Dette programmet spør brukeren om navnet, og skriver ut `Hei, <navn>`. Prøv det selv!
#
# All input er tekst. Hvis vi ønsker tall, må vi gjøre teksten om til et tall. Det enkleste er å sende teksten igjennom `float()`-funksjonen. Alternativt kan vi bruke `int()`-funksjonen hvis vi ønsker heltall som input.
#
# ```
# a = float(input("a: "))
# b = float(input("b: "))
# print("Summen av ", a, "og", b, "er",  a + b)
# ```
#
# Dette programmet tar to tall `a` og `b` og skriver ut summen deres. Prøv det selv!

# %% [markdown]
# #### Avrunding
#
# Vi kan runde av lange desimaltall ved å bruke `round`-funksjonen. Denne ligger ikke i en pakke og må derfor ikke importeres.

# %%
from math import pi

print(pi)           # Skriver ut pi med mange desimaler
print(round(pi, 2)) # Skriver ut pi rundet av til to desimaler.
# Out:
# 3.141592653589793
# 3.14

# %% [markdown]
# ```{admonition} Merk deg
# :class: note
# `round()`-funksjonen runder ikke alltid opp på tall som ender med `.5`. Dette gjør funksjonen for å unngå å runde opp mer enn man runder ned i et tallmateriale. Utforsk gjerne hvordan dette fungerer selv!
# ```

# %% [markdown]
# ---
#
# #### Oppgaver
#
# ##### Oppgave 1
#
# Lag en kalkulator som tar et tall som input og skriver ut kvadratroten av tallet.
#
# ##### Oppgave 2
#
# ```{sidebar}
# Formelen for omkretsen til en sirkel er $2\pi r$.
#
# Formelen for arealet til en sirkel er $\pi r^2$.
# ```
#
# Lag en kalkulator som tar et tall `r` som input og skriver ut omkretsen og arealet til en sirkel.
#
# Skriv ut svarene rundet av til to desimaler.
#
# ##### Oppgave 3
#
# Vi skal lage et program som simulerer terningkast.
#
# 1. Lag en variabel `a` som skal være et tall fra input fra brukeren.
# 2. Lag en variabel `b` som skal være et tilfeldig tall mellom `1` og `6`.
# 3. Skriv ut `Terningkast: ` etterfulgt av verdien til `b`.
#
# Prøv programmet et par ganger. Klarer du å gjette riktig?
#
# Bonus:
#
# Modifiser `terningkast` til å bli en verdi mellom `1` og `5379616`.
#
# Å gjette riktig tall nå er like sannsynlig som å vinne førstepremien i lotto 💸
