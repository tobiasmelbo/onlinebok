# %% [markdown]
# (Ekstra Python)=
# # Ekstra Python
#
# I dette kapitlet skal vi jobbe med litt mer avanserte emner.
#
# ```{admonition} Til læreren 🧑‍🏫
# :class: note
# Dette kapitlet bygger videre på emnene fra introduksjonskapitlet.
# ```
