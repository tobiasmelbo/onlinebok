# %% [markdown]
# (Plotting: Reelle datasett)=
# ### Plotting: Reelle datasett
#
# Pakken `pandas` lar oss lese inn og visualisere data fra filer på en litt enklere måte. Mange Python-installasjoner vil inkludere denne pakken, men man kan også installere pakken ved å skrive `pip install pandas` i terminalvinduet.
