# %% [markdown]
# (Plotting)=
# ### Plotting

# %% [markdown]
# I denne delen skal vi lære om plotting.
#
# For å plotte skal vi bruke en pakke som heter `matplotlib`. Mange Python-installasjoner vil inkludere denne pakken, men man kan også installere pakken ved å skrive `pip install matplotlib` i terminalvinduet.

# %% [markdown]
# #### Et enkelt plot
#
# La oss plotte den matematiske funksjonen $x^2$ i intervallet $[0, 5]$.

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x**2

x = np.linspace(0, 5, 100) # Hundre punkter mellom 0 og 5
y = f(x) # Setter x inn i funksjonen f. y blir funksjonsverdier

plt.plot(x, y) # Lager plot
plt.show() # Viser plot

# %% [markdown]
# #### Stil
#
# "Du må ha med navn på aksene! 😠" - En gretten mattelærer (sikkert)
#
# La oss få med litt stil på plottene våre.

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x**2

def g(x):
    return x**3

x = np.linspace(0, 5, 100)

plt.title("Sammenlikning av x**2 og x**3") # Tittel
plt.xlabel("x-verdier") # Gir navn til x-aksen
plt.ylabel("funksjonsverdier") # Gir navn til y-aksen
plt.plot(x, f(x), label="f(x)=x**2") # label gir navn til funksjonen
plt.plot(x, g(x), label="g(x)=x**3", color="red") # label gir navn til funksjonen, color gir farge
plt.grid() # Viser rutenett
plt.legend() # Lager boksen med funksjonenes navn
plt.show() # Viser plottet

# %% [markdown]
# "Wow! For et fint plott! 🤓" - En fornøyd mattelærer (sikkert)
#
# Undersøk koden grundig. Legg merke til hvordan vi kan sette inn funksjonsverdier i selve `plot()`-funksjonen.
#
# Legg også merke til hvordan vi kan plotte flere grafer med `plot()` før vi kjører `show()`-funksjonen. Vi kan tenke på `plot()` som en funksjon som *tegner* og `show()` som å en funksjon som *viser det vi har tegnet*.

# %% [markdown]
# ##### Endre på aksene
#
# Aksene settes automatisk, men hvis vi ønsker å endre på disse så kan vi bruke `plt.xlim()`- og `plt.ylim()`-funksjonene.
#
# - `plt.xlim(start, slutt)` gjør at plottet bare viser `x`-verdier mellom `start` og `slutt`.
# - `plt.ylim(start, slutt)` gjør at plottet bare viser `y`-verdier mellom `start` og `slutt`.

# %% [markdown]
# #### `scatter`-plot
#
# Noen ganger ønsker vi å plotte punkter. Da kan vi bruke `scatter()`-funksjonen.

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x**2

x = np.linspace(-5, 5, 9) # 9 x-verdier mellom -5 og 5
y = f(x)

plt.scatter(x, y)
plt.show()

# %% [markdown]
# #### `bar`-plot
#
# Vi kan lage søylediagrammer med `plt.bar()`.

# %%
import matplotlib.pyplot as plt

frukter = ['eple', 'blåbær', 'drue', 'appelsin']
antall = [40, 100, 30, 55]
fargeliste = ['red', 'blue', 'green', 'orange']

plt.bar(frukter, antall, color = fargeliste)
plt.ylabel("Antall frukter")
plt.show()

# %% [markdown]
# Fint, men for å unngå at plottet ser ut som en badeball så kan vi bytte ut fargene `['red', 'blue', 'green', 'orange']` med fargene fra en litt finere fargepalett `['tab:red', 'tab:blue', 'tab:green', 'tab:orange']`.

# %%
import matplotlib.pyplot as plt

frukter = ['eple', 'blåbær', 'drue', 'appelsin']
antall = [40, 100, 30, 55]
fargeliste = ['tab:red', 'tab:blue', 'tab:green', 'tab:orange']

plt.bar(frukter, antall, color = fargeliste)
plt.ylabel("Antall frukter")
plt.show()

# %% [markdown]
# #### `pie()`-plot
#
# Vi kan lage sektordiagrammer eller kakediagrammer med `plt.pie()`.

# %%
import matplotlib.pyplot as plt

frukter = ['eple', 'blåbær', 'drue', 'appelsin']
antall = [40, 100, 30, 55]
fargeliste = ['tab:red', 'tab:blue', 'tab:green', 'tab:orange']

plt.pie(antall, labels=frukter, colors=fargeliste, autopct="%.1f%%")
plt.title("Antall frukter")
plt.show()

# %% [markdown]
# Vi ser at sektordiagrammet fungerer ganske likt som søylediagrammet. Parameteren `autopct` gjør sånn at de prosentvise inndelingene skrives inn i hver sektor.

# %% [markdown]
# ---
#
# #### Oppgaver
#
# ##### Oppgave 1
#
# Lag en array `x` med 100 jevnt fordelte tall i intervallet $[-2, 2]$.
#
# Plott disse matematiske funksjonene i samme koordinatsystem:
#
# 1. $f(x) = x^2$
# 2. $g(x) = abs(x)$
# 3. $h(x) = abs(x^3)$
#
# Få med `legend()` og tittel. Gi funksjonene dine egne farger. Se gjerne [dokumentasjonen](https://matplotlib.org/stable/gallery/color/named_colors.html#css-colors) for de ulike fargene.

# %% [markdown]
# ##### Oppgave 2
#
# Finn høyden til medelevene dine (eller finn på ca 10 høyder selv).
#
# Del høydene opp i blokker på 5cm og tell hvor mange som havner i hver blokk.
#
# Lag et søylediagram av høydene.
