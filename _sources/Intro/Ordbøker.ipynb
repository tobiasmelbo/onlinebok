# %% [markdown]
# (Ordbøker)=
# ### Ordbøker
#
# Denne siden forutsetter at du har vært igjennom {ref}`lister`.
#
# Ordbøker (*dictionaries*) er en måte å lagre data. I {ref}`lister` lagrer vi data i en rekkefølge. I ordbøker lagrer vi data i par med `keys` og `values`, nøkler og verdier. En nøkkel er forbundet med sin verdi.

# %%
land = {"NO" : "Norge", "SE" : "Sverige"}

print(land["NO"])
# Out:
# Norge

# %% [markdown]
# I koden over lager vi landkoder.  `"NO"` og `"SE"` er landkodene, og `"Norge"` og `"Sverige"` er de tilhørende landene. Vi knytter sammen nøklene og verdiene med kolon `:`. For å hente verdier fra ordboken `land` så skriver vi inn nøkkelen (f.eks `land["NO"]`) og så får vi ut verdien (f.eks`"Norge"`).
#
# Dersom vi skal sette sammen en enkel ordbok så er det vanlig å gjøre det over flere linjer. Det er litt mer oversiktlig enn eksemplet over.

# %%
land = {
    "NO" : "Norge",
    "SE" : "Sverige"
}

print(land["SE"])
# Out:
# Sverige

# %% [markdown]
# #### Legge til og fjerne data
#
# For å legge til data så setter vi en ny nøkkel lik en verdi.

# %%
land = {
    "NO" : "Norge",
    "SE" : "Sverige"
}

land["DK"] = "Danmark" # Verdien "Danmark" legges inn i ordboken under nøkkelen "DK"

print(land["DK"])
# Out:
# Danmark

# %% [markdown]
# Vi kan fjerne data ved å bruke `pop()`-metoden.

# %%
land = {
    "NO" : "Norge",
    "SE" : "Sverige",
    "DK" : "Danmark"
}

land.pop("NO") # Fjerner både nøkkel og verdi for nøkkelen "NO"

print(land)
# Out:
# {'SE': 'Sverige', 'DK': 'Danmark'}

# %% [markdown]
# #### Løkker og ordbøker
#
# Vi kan gå igjennom ordbøker med `for`-løkker på denne måten.

# %%
land = {
    "NO" : "Norge",
    "SE" : "Sverige"
}

for x in land:
    print(x)         # Skriver ut nøkkelen
    print(land[x])   # Skriver ut verdien til nøkkelen
# Out:
# NO
# Norge
# SE
# Sverige

# %% [markdown]
# ---
#
# #### Oppgaver
#
# ##### Oppgave 1
#
# Lag en ordbok `elev` som skal ha fag som nøkler og karakterer som verdier. Den kan starte slik
#
# ```
# elev = {
#     "Norsk" : 4,
#     "Gym" : 3
# }
# ```
#
# 1. Legg til fire nye fag og karakterer. Du kan bestemme både fag og karakterer.
# 2. Lag en løkke som skriver ut alle fagene og karakterene med en setning `Eleven har <karakter> i faget <fag>`.
# 3. Finn og skriv ut karaktersnittet til eleven.
#
# ##### Oppgave 2
#
# Ordbøker kan også ha lister og andre ordbøker som verdier.
#
# ```
# klasse = {
#     "Navn" : "10F",
#     "Fag" : "Naturfag",
#     "Karakterer" : [4, 5, 2, 5, 2, 1, 6, 3, 4, 3]
# }
# ```
#
# Finn gjennomsnittet av karakterene ved å bruke ordboken `klasse`.
#
# ##### Oppgave 3 (utfordring)
#
# En vanlig måte å lagre farger på er ved å oppgi en verdi for hver farge. Tallene er heltall i intervallet $[0,255]$. Vi bruker  `"R"` for rød, `"G"` for grønn og `"B"` for blå.
#
# 1. Lag en ordbok som heter `farge`.
# 2. Nøklene til ordboken skal hete `"R"`, `"G"` og `"B"`. Disse skal ha tilfeldige verdier i intervallet $[0,255]$.
#
# Vi skal generere en hel fargepallett.
#
# 3. Lag en liste `farger` som skal inneholde ti tilfeldig genererte farger som ordbøker slik du har laget over.
#
# ##### Oppgave 4 (utfordring)
#
# I *Dungeons & Dragons* har man
